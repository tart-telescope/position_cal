# %% [markdown]
# # Antenna Position Calibration
#
# Author: Tim Molteno. tim@elec.ac.nz.
#
# The antennas are laid out on five spiral arms.  This notebook will use measurements to infer the actual layout of the antennas.
#
# The other reference point is the center of the array. This is assumed to be the point [0,0]. Make sure that a marker is present at this reference point at the same height as the level of the antennas (otherwise the distances will be wrong).

# %%
import numpy as np
from scipy.optimize import minimize

# pip install numpy scipy pandas odfpy

# %%
site_name = 'bd-iub'
x0 = [0,0]
global_rot_degrees = +180
global_rot_index = 13

# %%
import pandas as pd

cols = [f"A {i}" for i in range(24)]
data = pd.read_excel('antenna_measurements.ods', "Sheet1", usecols=cols)
radius = data.loc[0]
radius
# Out:
# A 0      344.5
# A 1      880.5
# A 2     1220.5
# A 3     1462.5
# A 4     1661.5
# A 5      338.5
# A 6      872.5
# A 7     1210.5
# A 8     1449.5
# A 9     1646.5
# A 10     325.5
# A 11     860.5
# A 12    1200.5
# A 13    1442.5
# A 14    1640.5
# A 15     327.5
# A 16     862.5
# A 17    1207.5
# A 18    1452.5
# A 19    1652.5
# A 20     338.5
# A 21     875.5
# A 22    1217.5
# A 23    1463.5
# Name: 0, dtype: float64

# %% [markdown]
# ## Finding the antennas
#
# This is done by measuring the distance from each antenna to x0 as well as each other antenna. The distance $m_0$ are the measurements to $x_0$. The array m_ij are the distances between antennas.

# %%
n_ant = 24
m_0 = np.zeros(n_ant)
m_ij = np.zeros((n_ant,n_ant))

radius = data.loc[0]

for i in range(n_ant):
    m_ij[i,:] = data.loc[i+1]

# %% [markdown]
# The following are the measured distances from [x1, x0, x2] from the reference points in millimeters. Note that their order must be the same as the order of the variable called 'reference_points'. In this case, they are x1,x0,x2.

# %%
for i in range(n_ant):
    for j in range(n_ant):
        if not np.isnan(m_ij[i,j]):
            m_ij[j,i] = m_ij[i,j]

m_ij
# Out:
# array([[   nan,  545. ,  905. , 1180. , 1415. ,  395. ,  886. , 1273. ,
#         1564. , 1807. ,  640. , 1184. , 1540. , 1790. , 1988. ,  641. ,
#         1135. , 1429. , 1625. , 1772. ,  395. ,  776. , 1039. , 1227. ],
#        [ 545. ,    0. ,  393. ,  710. , 1005. ,  774. , 1024. , 1402. ,
#         1732. , 2025. , 1132. , 1656. , 2035. , 2306. , 2521. , 1183. ,
#         1657. , 1917. , 2068. , 2163. ,  886. , 1023. , 1098. , 1139. ],
#        [ 905. ,  393. ,    nan,  333. ,  650. , 1039. , 1102. , 1427. ,
#            nan,    nan, 1427. ,    nan,    nan,    nan, 2838. , 1544. ,
#            nan,    nan,    nan, 2553. , 1271. ,    nan,    nan, 1390. ],
#        [1180. ,  710. ,  333. ,    nan,  322. , 1225. , 1136. , 1395. ,
#         1713. , 2035. , 1620. , 2068. , 2464. , 2771. , 3027. , 1794. ,
#         2310. , 2603. , 2772. , 2876. , 1564. , 1733. , 1758. , 1712. ],
#        [1415. , 1005. ,  650. ,  322. ,    nan, 1383. , 1163. , 1335. ,
#         1630. , 1950. , 1772. , 2166. , 2555. , 2875. , 3150. , 1997. ,
#         2525. , 2842. , 3035. , 3155. , 1810. , 2029. , 2073. , 2035. ],
#        [ 395. ,  774. , 1039. , 1225. , 1383. ,    nan,  545. ,  906. ,
#         1179. , 1413. ,  396. ,  890. , 1277. , 1564. , 1806. ,  642. ,
#         1184. , 1542. , 1795. , 1994. ,  640. , 1134. , 1426. , 1623. ],
#        [ 886. , 1024. , 1102. , 1136. , 1163. ,  545. ,    nan,  395. ,
#          711. , 1001. ,  775. , 1028. , 1405. , 1735. , 2028. , 1134. ,
#         1660. , 2038. , 2313. , 2527. , 1183. , 1658. , 1920. , 2068. ],
#        [1273. , 1402. , 1427. , 1395. , 1335. ,  906. ,  395. ,    nan,
#          336. ,  648. , 1040. , 1105. , 1432. , 1763. , 2077. , 1429. ,
#         1921.5, 2311. , 2605. , 2844. , 1542. , 2037. , 2310. , 2462. ],
#        [1564. , 1732. ,    nan, 1713. , 1630. , 1179. ,  711. ,  336. ,
#            nan,    nan, 1225. ,    nan,    nan,    nan, 2037. , 1621. ,
#            nan,    nan,    nan, 3030. ,    nan,    nan,    nan, 2771. ],
#        [1807. , 2025. ,    nan, 2035. , 1950. , 1413. , 1001. ,  648. ,
#            nan,    nan, 1382. ,    nan,    nan,    nan, 1948. , 1767. ,
#            nan,    nan,    nan, 3149. ,    nan,    nan,    nan, 3029. ],
#        [ 640. , 1132. , 1427. , 1620. , 1772. ,  396. ,  775. , 1040. ,
#         1225. , 1382. ,    nan,  545. ,  909. , 1180. , 1412. ,  398. ,
#          891. , 1276. , 1567. , 1811. ,  641. , 1185. , 1541. , 1793. ],
#        [1184. , 1656. ,    nan, 2068. , 2166. ,  890. , 1028. , 1105. ,
#            nan,    nan,  545. ,    nan,    nan,    nan, 1002. ,  775. ,
#            nan,    nan,    nan, 2027. ,    nan,    nan,    nan, 2311. ],
#        [1540. , 2035. ,    nan, 2464. , 2555. , 1277. , 1405. , 1432. ,
#            nan,    nan,  909. ,    nan,    nan,    nan,  648. , 1037. ,
#            nan,    nan,    nan, 2072. ,    nan,    nan,    nan, 2601. ],
#        [1790. , 2306. ,    nan, 2771. , 2875. , 1564. , 1735. , 1763. ,
#            nan,    nan, 1180. ,    nan,    nan,    nan,  322. , 1224. ,
#            nan,    nan,    nan, 2030. ,    nan,    nan,    nan, 2770. ],
#        [1988. , 2521. , 2838. , 3027. , 3150. , 1806. , 2028. , 2077. ,
#         2037. , 1948. , 1412. , 1002. ,  648. ,  322. ,    nan, 1376. ,
#         1155. , 1326. , 1618. , 1938. , 1764. , 2157. , 2545. , 2867. ],
#        [ 641. , 1183. , 1544. , 1794. , 1997. ,  642. , 1134. , 1429. ,
#         1621. , 1767. ,  398. ,  775. , 1037. , 1224. , 1376. ,    nan,
#          544. ,  908. , 1181. , 1415. ,  396. ,  889. , 1275. , 1565. ],
#        [1135. , 1657. ,    nan, 2310. , 2525. , 1184. , 1660. , 1921.5,
#            nan,    nan,  891. ,    nan,    nan,    nan, 1155. ,  544. ,
#            nan,    nan,    nan, 1003. ,    nan,    nan,    nan, 1736. ],
#        [1429. , 1917. ,    nan, 2603. , 2842. , 1542. , 2038. , 2311. ,
#            nan,    nan, 1276. ,    nan,    nan,    nan, 1326. ,  908. ,
#            nan,    nan,    nan,  650. ,    nan,    nan,    nan, 1765. ],
#        [1625. , 2068. ,    nan, 2772. , 3035. , 1795. , 2313. , 2605. ,
#            nan,    nan, 1567. ,    nan,    nan,    nan, 1618. , 1181. ,
#            nan,    nan,    nan,  324. ,    nan,    nan,    nan, 1717. ],
#        [1772. , 2163. , 2553. , 2876. , 3155. , 1994. , 2527. , 2844. ,
#         3030. , 3149. , 1811. , 2027. , 2072. , 2030. , 1938. , 1415. ,
#         1003. ,  650. ,  324. ,    nan, 1387. , 1169. , 1340. , 1633. ],
#        [ 395. ,  886. , 1271. , 1564. , 1810. ,  640. , 1183. , 1542. ,
#            nan,    nan,  641. ,    nan,    nan,    nan, 1764. ,  396. ,
#            nan,    nan,    nan, 1387. ,    nan,    nan,    nan, 1181. ],
#        [ 776. , 1023. ,    nan, 1733. , 2029. , 1134. , 1658. , 2037. ,
#            nan,    nan, 1185. ,    nan,    nan,    nan, 2157. ,  889. ,
#            nan,    nan,    nan, 1169. ,    nan,    nan,    nan,  714. ],
#        [1039. , 1098. ,    nan, 1758. , 2073. , 1426. , 1920. , 2310. ,
#            nan,    nan, 1541. ,    nan,    nan,    nan, 2545. , 1275. ,
#            nan,    nan,    nan, 1340. ,    nan,    nan,    nan,  335. ],
#        [1227. , 1139. , 1390. , 1712. , 2035. , 1623. , 2068. , 2462. ,
#         2771. , 3029. , 1793. , 2311. , 2601. , 2770. , 2867. , 1565. ,
#         1736. , 1765. , 1717. , 1633. , 1181. ,  714. ,  335. ,    nan]])

# %% [markdown]
# ## Plot the Initial Guess Points
#
# Initial Guesses are from JSON queried from the telescope API. These are converted to millimeters.

# %%
import json
import requests

def get_data(path):
    server = f"https://api.elec.ac.nz/tart/{site_name}/"

    r = requests.get('{}/{}'.format(server, path))
    return json.loads(r.text)

def get_pos():
    return np.array(get_data('api/v1/imaging/antenna_positions'))

if True:
    with open('antenna_positions.json', "r") as f:
        data = f.read()
    cal_json = json.loads(data)
    current_pos = cal_json["antenna_positions"]
    current_pos = np.array(current_pos)
else:
    current_pos = get_pos()
    json_result = {}
    json_result["antenna_positions"] = current_pos.tolist()
    print(json.dumps(json_result, indent=4, separators=(',', ': ')))

# %%
def geo_angle(x,y):
    return 90 - np.degrees(np.arctan2(y,x))

geo_angle(1,0)
# Out:
# np.float64(90.0)

# %%
def i_y(i):
    return 2*i+1

def i_x(i):
    return 2*i


initial_guess = np.zeros(2*n_ant)

for i in range(n_ant):
    x,y = current_pos[i][0:2]*1000
    initial_guess[i_x(i)] = x
    initial_guess[i_y(i)] = y
    
    print(f"{i} : {x},{y}, geo: {geo_angle(x,y)}")

pos_i = initial_guess.reshape((24,2))
#pos_i = current_pos*1000

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,12))

ax.scatter(pos_i[:,0], pos_i[:,1])
for i in range(0,pos_i.shape[0]):
    ax.text(pos_i[i,0], pos_i[i,1],f"{i}")

ax.grid(True)
ax.set_title('Initial positions')
ax.set_xlabel('x (mm)')
ax.set_ylabel('y (mm)')
plt.savefig('initial_positions.png')
plt.show()
# Out:
# 0 : 35.0,346.0, geo: 5.776167677696009
# 1 : 244.0,848.0, geo: 16.052424007156645
# 2 : 747.0,939.0, geo: 38.50320167158282
# 3 : 845.0,1238.0, geo: 34.3155887482581
# 4 : 1221.0,1203.0, geo: 45.42545588925691
# 5 : 324.0,84.0, geo: 75.46554491945987
# 6 : 868.0,37.0, geo: 87.55914604391093
# 7 : 1145.0,-110.0, geo: 95.48755706009126
# 8 : 1388.0,-424.0, geo: 106.98662825761724
# 9 : 1509.0,-704.0, geo: 115.01065731593116
# 10 : 171.0,-283.0, geo: 148.8579376757614
# 11 : 249.0,-856.0, geo: 163.78092834300574
# 12 : 214.0,-1181.0, geo: 169.7293115297287
# 13 : -0.0,-1439.0, geo: 180.0
# 14 : -260.0,-1627.0, geo: 189.07928887742102
# 15 : -221.0,-242.0, geo: 222.40305117844758
# 16 : -729.0,-591.0, geo: 230.96833219751693
# 17 : -1076.0,-546.0, geo: 243.09517057026116
# 18 : -1293.0,-468.0, geo: 250.10232980547687
# 19 : -1642.0,-224.0, geo: 262.23171974201296
# 20 : -329.0,122.0, geo: -69.65417851171318
# 21 : -729.0,492.0, geo: -55.98469975426582
# 22 : -871.0,859.0, geo: -45.39742099860618
# 23 : -827.0,1201.0, geo: -34.5510197612047

# %% [markdown]
# ## Criteria for Optimality
#
# The function below is minimized when the positions (in variable x) are consistent with the measured distances m[i,j]. The initial value of this function is more than 3 million.
#
# Note that the x input is a 1D vector of with 48 entries as [p0.x, p0.y, p1.x, p1.y]

# %%
def geo_angle(x,y):
    return 90 - np.degrees(np.arctan2(y,x))

geo_angle(1,0)
# Out:
# np.float64(90.0)

# %%
def dist(a,b):
    return np.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2)


def p(x, i):
    return [x[i_x(i)],x[i_y(i)]]

max_err = 4200
def bounds():
    ret = [(0,0)]*48
    for i in range(n_ant):
        _x,_y = pos_i[i,0], pos_i[i,1]
        ret[i_x(i)] = (_x - max_err, _x + max_err)
        ret[i_y(i)] = (_y - max_err, _y + max_err)
    
    return ret

bnd = bounds()

center = [0,0]

def angle(x, i):
    _x, _y = p(x, i)
    return geo_angle(_x, _y)
    
def radius_model(x):
    ret = []
    
    for i in range(n_ant):
        p_i = p(x,i)
        ret.append(dist(center, p_i))
        
    return np.array(ret)

non_nan_ij = []
non_nan_indices = []
for i in range(n_ant):
    for j in range(n_ant):
        if not np.isnan(m_ij[i,j]):
            non_nan_ij.append(m_ij[i,j])
            non_nan_indices.append([i,j])
non_nan_ij = np.array(non_nan_ij)
non_nan_indices = np.array(non_nan_indices)

def m_ij_model(x):
    ret = []
    for i in range(n_ant):
        p_i = p(x,i)

        for j in range(n_ant):
            p_j = p(x,j)
            if not np.isnan(m_ij[i,j]):
                ret.append(dist(p_j, p_i))
                
    return np.array(ret)
    
def radius_residual(x):
    predict = radius_model(x)
    return (predict - radius)

def m_ij_residual(x):
    predict = m_ij_model(x)
    return (predict - non_nan_ij)

def rot_residual(x):
    predict = angle(x, global_rot_index)
    return (predict - global_rot_degrees)

def f_old(x):
    ret = 0
    for i in range(n_ant):
        p_i = p(x,i)
        ret += (dist(center, p_i) - m_0[i])**2
        for j in range(n_ant):
            p_j = p(x,j)
            if not np.isnan(m_ij[i,j]):
                ret += (dist(p_j, p_i) - m_ij[i,j])**2
    return ret

def f(x):
    # This is the final criterion for optimality. The sum of squared residuals.
    ret = np.sum(radius_residual(x)**2)*10
    ret += np.sum(m_ij_residual(x)**2)
    ret += (rot_residual(x)**2)*100
    return ret

# %%
print(f(initial_guess))
# Out:
# 1324479.5083206845

# %% [markdown]
#  We can see that the initial value of this optimality condition is quite large.s

# %%
res = minimize(f, initial_guess, bounds=None, options={'maxiter': 500})
res
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1717.9191440131638
#         x: [ 3.257e+01  3.448e+02 ... -8.591e+02  1.188e+03]
#       nit: 83
#       jac: [-2.289e-04 -1.678e-04 ... -5.341e-04 -2.594e-04]
#  hess_inv: [[ 3.326e-02  4.074e-03 ...  3.475e-03 -5.002e-03]
#             [ 4.074e-03  1.982e-02 ... -1.027e-03 -3.097e-03]
#             ...
#             [ 3.475e-03 -1.027e-03 ...  1.767e-02  5.418e-04]
#             [-5.002e-03 -3.097e-03 ...  5.418e-04  1.255e-02]]
#      nfev: 7068
#      njev: 144

# %%
err = res.jac.reshape((24,2))
rms = err # np.sqrt(np.sum(err**2, axis=1))
for i in range(24):
    print(f"Ant {i}:\tJac: {rms[i,0]:06.2f}, \t{rms[i,1]:06.2f}")
# Out:
# Ant 0:	Jac: -00.00, 	-00.00
# Ant 1:	Jac: 000.00, 	000.00
# Ant 2:	Jac: 000.00, 	000.00
# Ant 3:	Jac: -00.00, 	000.00
# Ant 4:	Jac: 000.00, 	000.00
# Ant 5:	Jac: 000.00, 	000.00
# Ant 6:	Jac: -00.00, 	000.00
# Ant 7:	Jac: 000.00, 	-00.00
# Ant 8:	Jac: 000.00, 	-00.00
# Ant 9:	Jac: -00.00, 	-00.00
# Ant 10:	Jac: 000.00, 	000.00
# Ant 11:	Jac: -00.00, 	-00.00
# Ant 12:	Jac: 000.00, 	-00.00
# Ant 13:	Jac: -00.00, 	-00.00
# Ant 14:	Jac: 000.00, 	000.00
# Ant 15:	Jac: 000.00, 	000.00
# Ant 16:	Jac: -00.00, 	-00.00
# Ant 17:	Jac: 000.00, 	000.00
# Ant 18:	Jac: -00.00, 	-00.00
# Ant 19:	Jac: 000.00, 	000.00
# Ant 20:	Jac: 000.00, 	000.00
# Ant 21:	Jac: 000.00, 	-00.00
# Ant 22:	Jac: 000.00, 	000.00
# Ant 23:	Jac: -00.00, 	-00.00

# %% [markdown]
# The optimized positions are now known. The final value of the function is 32. Far closer to zero than 3 million!
#
# We can recover the x,y coordinates by reshaping the array

# %%
pos = res.x.reshape((24,2))
pos
# Out:
# array([[ 3.25723523e+01,  3.44793823e+02],
#        [ 2.26688972e+02,  8.51188050e+02],
#        [ 5.29031986e+02,  1.10212229e+03],
#        [ 8.51779526e+02,  1.19191863e+03],
#        [ 1.17495360e+03,  1.17949873e+03],
#        [ 3.28829613e+02,  8.46860370e+01],
#        [ 8.71593958e+02,  5.58756749e+01],
#        [ 1.20326619e+03, -1.55524480e+02],
#        [ 1.38487666e+03, -4.36271818e+02],
#        [ 1.46968977e+03, -7.46917670e+02],
#        [ 1.72172131e+02, -2.78069953e+02],
#        [ 3.09686183e+02, -8.04209778e+02],
#        [ 2.08048672e+02, -1.18417719e+03],
#        [ 3.06707592e-04, -1.44403126e+03],
#        [-2.71139640e+02, -1.61919359e+03],
#        [-2.22739222e+02, -2.42382118e+02],
#        [-6.77731853e+02, -5.37266245e+02],
#        [-1.07027821e+03, -5.62282457e+02],
#        [-1.38442279e+03, -4.46484093e+02],
#        [-1.63766133e+03, -2.45932585e+02],
#        [-3.07585029e+02,  1.43911568e+02],
#        [-7.29632649e+02,  4.86693600e+02],
#        [-8.72185548e+02,  8.52750897e+02],
#        [-8.59072506e+02,  1.18794591e+03]])

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6))


ax[0].scatter(pos_i[:,0], pos_i[:,1], label='initial', color='blue')
for i in range(0,pos_i.shape[0]):
    ax[0].text(pos_i[i,0], pos_i[i,1],f"{i}", color='orange')
ax[0].set_title('Initial Guess')
ax[0].grid(True)
ax[0].set_xlabel('x (mm)')
ax[0].set_ylabel('y (mm)')

ax[1].scatter(pos[:,0], pos[:,1], label='final', color='orange')
for i in range(0,pos.shape[0]):
    ax[1].text(pos[i,0], pos[i,1],f"{i}", color='blue')
ax[1].set_title('Final Solution')
ax[1].grid(True)
ax[1].set_xlabel('x (mm)')
ax[1].set_ylabel('y (mm)')
plt.savefig('final_positions.png')
plt.show()

# %% [markdown]
# ![title](drone_view.jpeg)

# %%
# Differences plot
diff = pos - pos_i[:,0:2]


fig, ax = plt.subplots(figsize=(12,12))

ax.scatter(diff[:,0], diff[:,1], color='red')

for i in range(0,diff.shape[0]):
    ax.text(diff[i,0], diff[i,1],f"{i}")

ax.grid(True)
ax.set_title("Differences from initial position")
ax.set_xlabel('x (mm)')
ax.set_ylabel('y (mm)')
plt.savefig('differences.png')
plt.show()

# %%
# Residual plot
rres = radius_residual(res.x)
rres
# Out:
# A 0     1.828946
# A 1     0.356961
# A 2     2.017230
# A 3     2.490914
# A 4     3.352309
# A 5     1.059478
# A 6     0.883145
# A 7     2.775474
# A 8     2.469856
# A 9     2.097597
# A 10    1.556786
# A 11    1.276595
# A 12    1.814380
# A 13    1.531260
# A 14    1.238280
# A 15    1.683614
# A 16    2.355758
# A 17    1.490077
# A 18    2.138959
# A 19    3.524598
# A 20    1.086644
# A 21    1.560125
# A 22    2.291672
# A 23    2.522185
# Name: 0, dtype: float64

# %%
# ij resdual
ijres = m_ij_residual(res.x)
plt.hist(ijres, bins='fd');
plt.title("Histogram of residuals")
plt.xlabel("Residual (mm)")
plt.grid(True)
plt.savefig("residual_histogram.png")

# %% [markdown]
# The API expects 3D coordinates (with a z value which is zero in this case). Therefore we add a column of zeros.

# %%
absres = np.abs(ijres)
pct = 90
p95 = np.percentile(absres, pct)

print(f"{pct}th percentile of residuals is {p95:4.2f} mm")
ijres_matrix = np.zeros_like(m_ij)
big_res = []
for r, i, j in zip(ijres, non_nan_indices[:,0], non_nan_indices[:,1]):
    if np.abs(r) > p95 and i > j:
        big_res.append([r,i,j])
    ijres_matrix[i,j] = r

for res in sorted(big_res):
    r,i,j = res
    print(f" res[{i},{j}] = {r:3.1f}")
# Out:
# 90th percentile of residuals is 2.10 mm
#  res[15,2] = -3.6
#  res[15,4] = -3.2
#  res[18,4] = -2.8
#  res[10,4] = -2.8
#  res[22,6] = -2.8
#  res[1,0] = -2.7
#  res[22,7] = -2.6
#  res[21,10] = -2.6
#  res[16,0] = -2.5
#  res[7,3] = -2.5
#  res[16,10] = -2.5
#  res[12,5] = -2.4
#  res[10,9] = -2.4
#  res[8,0] = -2.3
#  res[21,4] = -2.3
#  res[21,19] = -2.3
#  res[12,3] = -2.2
#  res[9,0] = -2.2
#  res[23,1] = -2.2
#  res[12,10] = -2.2
#  res[16,7] = -2.2

# %% [markdown]
# ## Output best estimates
#
# Write some json files...

# %%
result = np.zeros((n_ant, 3))
result[:,:-1] = np.round(pos/1000.0, 3)
result
# Out:
# array([[ 0.033,  0.345,  0.   ],
#        [ 0.227,  0.851,  0.   ],
#        [ 0.529,  1.102,  0.   ],
#        [ 0.852,  1.192,  0.   ],
#        [ 1.175,  1.179,  0.   ],
#        [ 0.329,  0.085,  0.   ],
#        [ 0.872,  0.056,  0.   ],
#        [ 1.203, -0.156,  0.   ],
#        [ 1.385, -0.436,  0.   ],
#        [ 1.47 , -0.747,  0.   ],
#        [ 0.172, -0.278,  0.   ],
#        [ 0.31 , -0.804,  0.   ],
#        [ 0.208, -1.184,  0.   ],
#        [ 0.   , -1.444,  0.   ],
#        [-0.271, -1.619,  0.   ],
#        [-0.223, -0.242,  0.   ],
#        [-0.678, -0.537,  0.   ],
#        [-1.07 , -0.562,  0.   ],
#        [-1.384, -0.446,  0.   ],
#        [-1.638, -0.246,  0.   ],
#        [-0.308,  0.144,  0.   ],
#        [-0.73 ,  0.487,  0.   ],
#        [-0.872,  0.853,  0.   ],
#        [-0.859,  1.188,  0.   ]])

# %%
json_result = {}
json_result["antenna_positions"] = result.tolist()

json_fname = f"{site_name}_processed_antenna_positions.json"
f = open(json_fname, "w")
f.write(json.dumps(json_result))
f.close()

pos_json = json.dumps(json_result, indent=4, separators=(',', ': '))
print(pos_json)
# Out:
# {
#     "antenna_positions": [
#         [
#             0.033,
#             0.345,
#             0.0
#         ],
#         [
#             0.227,
#             0.851,
#             0.0
#         ],
#         [
#             0.529,
#             1.102,
#             0.0
#         ],
#         [
#             0.852,
#             1.192,
#             0.0
#         ],
#         [
#             1.175,
#             1.179,
#             0.0
#         ],
#         [
#             0.329,
#             0.085,
#             0.0
#         ],
#         [
#             0.872,
#             0.056,
#             0.0
#         ],
#         [
#             1.203,
#             -0.156,
#             0.0
#         ],
#         [
#             1.385,
#             -0.436,
#             0.0
#         ],
#         [
#             1.47,
#             -0.747,
#             0.0
#         ],
#         [
#             0.172,
#             -0.278,
#             0.0
#         ],
#         [
#             0.31,
#             -0.804,
#             0.0
#         ],
#         [
#             0.208,
#             -1.184,
#             0.0
#         ],
#         [
#             0.0,
#             -1.444,
#             0.0
#         ],
#         [
#             -0.271,
#             -1.619,
#             0.0
#         ],
#         [
#             -0.223,
#             -0.242,
#             0.0
#         ],
#         [
#             -0.678,
#             -0.537,
#             0.0
#         ],
#         [
#             -1.07,
#             -0.562,
#             0.0
#         ],
#         [
#             -1.384,
#             -0.446,
#             0.0
#         ],
#         [
#             -1.638,
#             -0.246,
#             0.0
#         ],
#         [
#             -0.308,
#             0.144,
#             0.0
#         ],
#         [
#             -0.73,
#             0.487,
#             0.0
#         ],
#         [
#             -0.872,
#             0.853,
#             0.0
#         ],
#         [
#             -0.859,
#             1.188,
#             0.0
#         ]
#     ]
# }

# %% [markdown]
# The position file above is in a format suitable for uploading to the telescope api. Also for using as the calibrated_antenna_positions.json file in TART/software/containers/telescope_web_api/config_data.

# %%
print(f"tart_upload_antenna_positions --api https://api.elec.ac.nz/tart/{site_name} --pw=xxxx --file {json_fname}")
# Out:
# tart_upload_antenna_positions --api https://api.elec.ac.nz/tart/bd-iub --pw=xxxx --file bd-iub_processed_antenna_positions.json
