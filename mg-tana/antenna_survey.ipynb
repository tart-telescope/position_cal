# %% [markdown]
# # Antenna Position Calibration
#
# Author: Tim Molteno. tim@elec.ac.nz.
#
# The antennas are laid out on five spiral arms.  This notebook will use measurements to infer the actual layout of the antennas.
#
# The other reference point is the center of the array. This is assumed to be the point [0,0]. Make sure that a marker is present at this reference point at the same height as the level of the antennas (otherwise the distances will be wrong).

# %%
import numpy as np
from scipy.optimize import minimize

# pip install numpy scipy pandas odfpy

# %%
site_name = 'mg-tana'
x0 = [0,0]
global_rot_degrees = -57.84888939188495
global_rot_index = 9

# %%
import pandas as pd

cols = [f"A {i}" for i in range(24)]
data = pd.read_excel('antenna_measurements.ods', "Sheet1", usecols=cols)
radius = data.loc[0]
radius
# Out:
# A 0      336.0
# A 1      829.0
# A 2     1198.0
# A 3     1459.0
# A 4     1683.0
# A 5      333.0
# A 6      825.0
# A 7     1196.0
# A 8     1460.0
# A 9     1685.0
# A 10     334.0
# A 11     825.0
# A 12    1200.0
# A 13    1465.0
# A 14    1688.0
# A 15     342.0
# A 16     833.0
# A 17    1205.0
# A 18    1465.0
# A 19    1693.0
# A 20     341.0
# A 21     835.0
# A 22    1203.0
# A 23    1470.0
# Name: 0, dtype: float64

# %% [markdown]
# ## Finding the antennas
#
# This is done by measuring the distance from each antenna to x0 as well as each other antenna. The distance $m_0$ are the measurements to $x_0$. The array m_ij are the distances between antennas.

# %%
n_ant = 24
m_0 = np.zeros(n_ant)
m_ij = np.zeros((n_ant,n_ant))

radius = data.loc[0]

for i in range(n_ant):
    m_ij[i,:] = data.loc[i+1]

# %% [markdown]
# The following are the measured distances from [x1, x0, x2] from the reference points in millimeters. Note that their order must be the same as the order of the variable called 'reference_points'. In this case, they are x1,x0,x2.

# %%
for i in range(n_ant):
    for j in range(n_ant):
        if not np.isnan(m_ij[i,j]):
            m_ij[j,i] = m_ij[i,j]

m_ij
# Out:
# array([[  nan,  500.,  890., 1176., 1434.,  397.,  841., 1250., 1561.,
#         1833.,  642., 1139., 1527., 1801., 2027.,  642., 1101., 1428.,
#         1644., 1814.,  398.,  750., 1040., 1246.],
#        [ 500.,   nan,  414.,  743., 1050.,  748.,  976., 1366., 1711.,
#         2030., 1100., 1580., 1984., 2277., 2517., 1142., 1584., 1878.,
#         2051., 2169.,  842.,  980., 1091., 1160.],
#        [ 890.,  414.,   nan,  348.,  682., 1038., 1086., 1410., 1754.,
#         2096., 1425., 1872., 2281., 2595., 2861., 1527., 1987., 2289.,
#         2464., 2572., 1252., 1370., 1416., 1401.],
#        [1176.,  743.,  348.,   nan,  346., 1244., 1152., 1393., 1719.,
#         2067., 1640., 2045., 2454., 2783., 3070., 1801., 2277., 2601.,
#         2790., 2910., 1561., 1714., 1760., 1728.],
#        [1434., 1050.,  682.,  346.,   nan, 1420., 1204., 1345., 1635.,
#         1979., 1810., 2163., 2565., 2905., 3209., 2025., 2515., 2862.,
#         3074., 3214., 1832., 2033., 2101., 2076.],
#        [ 397.,  748., 1038., 1244., 1420.,   nan,  499.,  888., 1180.,
#         1438.,  400.,  842., 1251., 1563., 1833.,  645., 1140., 1527.,
#         1803., 2028.,  642., 1100., 1425., 1643.],
#        [ 841.,  976., 1086., 1152., 1204.,  499.,   nan,  415.,  745.,
#         1054.,  750.,  980., 1370., 1714., 2032., 1100., 1580., 1983.,
#         2277., 2519., 1141., 1581., 1874., 2048.],
#        [1250., 1366., 1410., 1393., 1345.,  888.,  415.,   nan,  347.,
#          685., 1039., 1093., 1414., 1759., 2100., 1428., 1875., 2285.,
#         2598., 2862., 1527., 1982., 2286., 2460.],
#        [1561., 1711., 1754., 1719., 1635., 1180.,  745.,  347.,   nan,
#          348., 1248., 1158., 1400., 1723., 2075., 1644., 2050., 2460.,
#         2788., 3072., 1800., 2275., 2598., 2787.],
#        [1833., 2030., 2096., 2067., 1979., 1438., 1054.,  685.,  348.,
#           nan, 1426., 1212., 1356., 1644., 1987., 1814., 2166., 2570.,
#         2909., 3212., 2027., 2516., 2863., 3071.],
#        [ 642., 1100., 1425., 1640., 1810.,  400.,  750., 1039., 1248.,
#         1426.,   nan,  498.,  886., 1178., 1436.,  396.,  839., 1249.,
#         1559., 1828.,  639., 1139., 1526., 1800.],
#        [1139., 1580., 1872., 2045., 2163.,  842.,  980., 1093., 1158.,
#         1212.,  498.,   nan,  412.,  742., 1052.,  745.,  973., 1364.,
#         1709., 2026., 1097., 1579., 1982., 2274.],
#        [1527., 1984., 2281., 2454., 2565., 1251., 1370., 1414., 1400.,
#         1356.,  886.,  412.,   nan,  347.,  683., 1034., 1084., 1408.,
#         1752., 2092., 1422., 1872., 2284., 2595.],
#        [1801., 2277., 2595., 2783., 2905., 1563., 1714., 1759., 1723.,
#         1644., 1178.,  742.,  347.,   nan,  348., 1243., 1152., 1394.,
#         1718., 2068., 1640., 2048., 2457., 2785.],
#        [2027., 2517., 2861., 3070., 3209., 1833., 2032., 2100., 2075.,
#         1987., 1436., 1052.,  683.,  348.,   nan, 1418., 1207., 1349.,
#         1639., 1980., 1810., 2165., 2567., 2906.],
#        [ 642., 1142., 1527., 1801., 2025.,  645., 1100., 1428., 1644.,
#         1814.,  396.,  745., 1034., 1243., 1418.,   nan,  498.,  888.,
#         1178., 1437.,  396.,  840., 1250., 1558.],
#        [1101., 1584., 1987., 2277., 2515., 1140., 1580., 1875., 2050.,
#         2166.,  839.,  973., 1084., 1152., 1207.,  498.,   nan,  413.,
#          742., 1053.,  747.,  977., 1368., 1711.],
#        [1428., 1878., 2289., 2601., 2862., 1527., 1983., 2285., 2460.,
#         2570., 1249., 1364., 1408., 1394., 1349.,  888.,  413.,   nan,
#          346.,  684., 1039., 1087., 1411., 1754.],
#        [1644., 2051., 2464., 2790., 3074., 1803., 2277., 2598., 2788.,
#         2909., 1559., 1709., 1752., 1718., 1639., 1178.,  742.,  346.,
#           nan,  349., 1243., 1154., 1397., 1722.],
#        [1814., 2169., 2572., 2910., 3214., 2028., 2519., 2862., 3072.,
#         3212., 1828., 2026., 2092., 2068., 1980., 1437., 1053.,  684.,
#          349.,   nan, 1421., 1207., 1350., 1640.],
#        [ 398.,  842., 1252., 1561., 1832.,  642., 1141., 1527., 1800.,
#         2027.,  639., 1097., 1422., 1640., 1810.,  396.,  747., 1039.,
#         1243., 1421.,   nan,  500.,  887., 1180.],
#        [ 750.,  980., 1370., 1714., 2033., 1100., 1581., 1982., 2275.,
#         2516., 1139., 1579., 1872., 2048., 2165.,  840.,  977., 1087.,
#         1154., 1207.,  500.,   nan,  412.,  743.],
#        [1040., 1091., 1416., 1760., 2101., 1425., 1874., 2286., 2598.,
#         2863., 1526., 1982., 2284., 2457., 2567., 1250., 1368., 1411.,
#         1397., 1350.,  887.,  412.,   nan,  348.],
#        [1246., 1160., 1401., 1728., 2076., 1643., 2048., 2460., 2787.,
#         3071., 1800., 2274., 2595., 2785., 2906., 1558., 1711., 1754.,
#         1722., 1640., 1180.,  743.,  348.,   nan]])

# %% [markdown]
# ## Plot the Initial Guess Points
#
# Initial Guesses are from JSON queried from the telescope API. These are converted to millimeters.

# %%
import json
import requests

def get_data(path):
    server = "https://api.elec.ac.nz/tart/mg-tana/"

    r = requests.get('{}/{}'.format(server, path))
    return json.loads(r.text)

def get_pos():
    return np.array(get_data('api/v1/imaging/antenna_positions'))

if True:
    # with open('hammanskraal_antenna_positions_nonaligned.json', "r") as f:
    with open('antenna_positions.json', "r") as f:
        data = f.read()
    cal_json = json.loads(data)
    current_pos = cal_json["antenna_positions"]
    current_pos = np.array(current_pos)
else:
    current_pos = get_pos()
    json_result = {}
    json_result["antenna_positions"] = current_pos.tolist()
    print(json.dumps(json_result, indent=4, separators=(',', ': ')))

# %%
def geo_angle(x,y):
    return 90 - np.degrees(np.arctan2(y,x))

geo_angle(1,0)
# Out:
# np.float64(90.0)

# %%
def i_y(i):
    return 2*i+1

def i_x(i):
    return 2*i


initial_guess = np.zeros(2*n_ant)

for i in range(n_ant):
    x,y = current_pos[i][0:2]*1000
    initial_guess[i_x(i)] = x
    initial_guess[i_y(i)] = y
    
    print(f"{i} : {x},{y}, geo: {geo_angle(x,y)}")

pos_i = initial_guess.reshape((24,2))
#pos_i = current_pos*1000

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,12))

ax.scatter(pos_i[:,0], pos_i[:,1])
for i in range(0,pos_i.shape[0]):
    ax.text(pos_i[i,0], pos_i[i,1],f"{i}")

ax.grid(True)
ax.set_title('Initial positions')
ax.set_xlabel('x (mm)')
ax.set_ylabel('y (mm)')
plt.savefig('initial_positions.png')
plt.show()
# Out:
# 0 : -68.0,-330.0, geo: 191.6434314987617
# 1 : -285.0,-780.0, geo: 200.07152586453873
# 2 : -610.0,-1033.0, geo: 210.56240595649206
# 3 : -947.0,-1113.0, geo: 220.39291634633756
# 4 : -1293.0,-1078.0, geo: 230.18135563913455
# 5 : -332.0,-35.0, geo: 263.98201069677896
# 6 : -826.0,31.0, geo: -87.8506828751033
# 7 : -1168.0,262.0, geo: -77.35697468668371
# 8 : -1351.0,557.0, geo: -67.59427314768186
# 9 : -1427.0,897.0, geo: -57.84688257683203
# 10 : -129.0,309.0, geo: -22.65935204000587
# 11 : -218.0,798.0, geo: -15.279417166195273
# 12 : -105.0,1195.0, geo: -5.021461042201864
# 13 : 118.0,1460.0, geo: 4.620711139128019
# 14 : 418.0,1636.0, geo: 14.33251317185217
# 15 : 258.0,225.0, geo: 48.90854429445945
# 16 : 695.0,462.0, geo: 56.38609830421346
# 17 : 1108.0,477.0, geo: 66.70786034854962
# 18 : 1428.0,347.0, geo: 76.34200341874808
# 19 : 1689.0,117.0, geo: 86.03735087009717
# 20 : 296.0,-169.0, geo: 119.72403130531778
# 21 : 658.0,-514.0, geo: 127.99535275870554
# 22 : 800.0,-901.0, geo: 138.39805251604912
# 23 : 776.0,-1247.0, geo: 148.10626402696548

# %% [markdown]
# ## Criteria for Optimality
#
# The function below is minimized when the positions (in variable x) are consistent with the measured distances m[i,j]. The initial value of this function is more than 3 million.
#
# Note that the x input is a 1D vector of with 48 entries as [p0.x, p0.y, p1.x, p1.y]

# %%
def geo_angle(x,y):
    return 90 - np.degrees(np.arctan2(y,x))

geo_angle(1,0)
# Out:
# np.float64(90.0)

# %%
def dist(a,b):
    return np.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2)


def p(x, i):
    return [x[i_x(i)],x[i_y(i)]]

max_err = 4200
def bounds():
    ret = [(0,0)]*48
    for i in range(n_ant):
        _x,_y = pos_i[i,0], pos_i[i,1]
        ret[i_x(i)] = (_x - max_err, _x + max_err)
        ret[i_y(i)] = (_y - max_err, _y + max_err)
    
    return ret

bnd = bounds()

center = [0,0]

def angle(x, i):
    _x, _y = p(x, i)
    return geo_angle(_x, _y)
    
def radius_model(x):
    ret = []
    
    for i in range(n_ant):
        p_i = p(x,i)
        ret.append(dist(center, p_i))
        
    return np.array(ret)

non_nan_ij = []
non_nan_indices = []
for i in range(n_ant):
    for j in range(n_ant):
        if not np.isnan(m_ij[i,j]):
            non_nan_ij.append(m_ij[i,j])
            non_nan_indices.append([i,j])
non_nan_ij = np.array(non_nan_ij)
non_nan_indices = np.array(non_nan_indices)

def m_ij_model(x):
    ret = []
    for i in range(n_ant):
        p_i = p(x,i)

        for j in range(n_ant):
            p_j = p(x,j)
            if not np.isnan(m_ij[i,j]):
                ret.append(dist(p_j, p_i))
                
    return np.array(ret)
    
def radius_residual(x):
    predict = radius_model(x)
    return (predict - radius)

def m_ij_residual(x):
    predict = m_ij_model(x)
    return (predict - non_nan_ij)

def rot_residual(x):
    predict = angle(x, global_rot_index)
    return (predict - global_rot_degrees)

def f_old(x):
    ret = 0
    for i in range(n_ant):
        p_i = p(x,i)
        ret += (dist(center, p_i) - m_0[i])**2
        for j in range(n_ant):
            p_j = p(x,j)
            if not np.isnan(m_ij[i,j]):
                ret += (dist(p_j, p_i) - m_ij[i,j])**2
    return ret

def f(x):
    # This is the final criterion for optimality. The sum of squared residuals.
    ret = np.sum(radius_residual(x)**2)*10
    ret += np.sum(m_ij_residual(x)**2)
    ret += (rot_residual(x)**2)*100
    return ret

# %%
print(f(initial_guess))
# Out:
# 1363.4460029066865

# %% [markdown]
# We can see that the initial value of this optimality condition is quite large.

# %%
res = minimize(f, initial_guess, bounds=None, options={'maxiter': 500})
res
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1247.6096156445312
#         x: [-6.788e+01 -3.304e+02 ...  7.759e+02 -1.247e+03]
#       nit: 110
#       jac: [ 0.000e+00  7.629e-05 ... -2.899e-04 -2.136e-04]
#  hess_inv: [[ 2.750e-02 -2.164e-02 ... -5.857e-03 -1.253e-03]
#             [-2.164e-02  4.260e-02 ...  1.240e-02  6.198e-04]
#             ...
#             [-5.857e-03  1.240e-02 ...  1.228e-02 -1.841e-03]
#             [-1.253e-03  6.198e-04 ... -1.841e-03  3.639e-03]]
#      nfev: 7007
#      njev: 143

# %%
err = res.jac.reshape((24,2))
rms = err # np.sqrt(np.sum(err**2, axis=1))
for i in range(24):
    print(f"Ant {i}:\tJac: {rms[i,0]:06.2f}, \t{rms[i,1]:06.2f}")
# Out:
# Ant 0:	Jac: 000.00, 	000.00
# Ant 1:	Jac: 000.00, 	000.00
# Ant 2:	Jac: 000.00, 	-00.00
# Ant 3:	Jac: 000.00, 	000.00
# Ant 4:	Jac: 000.00, 	-00.00
# Ant 5:	Jac: 000.00, 	000.00
# Ant 6:	Jac: 000.00, 	000.00
# Ant 7:	Jac: 000.00, 	000.00
# Ant 8:	Jac: -00.00, 	-00.00
# Ant 9:	Jac: -00.00, 	-00.00
# Ant 10:	Jac: -00.00, 	000.00
# Ant 11:	Jac: 000.00, 	000.00
# Ant 12:	Jac: 000.00, 	-00.00
# Ant 13:	Jac: 000.00, 	000.00
# Ant 14:	Jac: -00.00, 	000.00
# Ant 15:	Jac: -00.00, 	-00.00
# Ant 16:	Jac: -00.00, 	000.00
# Ant 17:	Jac: -00.00, 	000.00
# Ant 18:	Jac: -00.00, 	-00.00
# Ant 19:	Jac: 000.00, 	-00.00
# Ant 20:	Jac: -00.00, 	000.00
# Ant 21:	Jac: -00.00, 	000.00
# Ant 22:	Jac: 000.00, 	000.00
# Ant 23:	Jac: -00.00, 	-00.00

# %% [markdown]
# The optimized positions are now known. The final value of the function is 32. Far closer to zero than 3 million!
#
# We can recover the x,y coordinates by reshaping the array

# %%
pos = res.x.reshape((24,2))
pos
# Out:
# array([[  -67.87743374,  -330.35391507],
#        [ -284.52164064,  -780.22279805],
#        [ -610.42476335, -1032.62975929],
#        [ -947.45826396, -1112.61071486],
#        [-1293.04016986, -1078.18157514],
#        [ -331.60136168,   -34.7687692 ],
#        [ -825.58229937,    30.79690413],
#        [-1168.1609375 ,   261.62191597],
#        [-1351.03188239,   556.77504387],
#        [-1426.90878134,   896.87443743],
#        [ -129.14284036,   308.50764598],
#        [ -218.0478315 ,   798.06684481],
#        [ -104.61563855,  1194.78162787],
#        [  118.15184483,  1460.21238586],
#        [  418.18249795,  1636.47896928],
#        [  257.63278958,   224.81868545],
#        [  694.9127953 ,   462.47270638],
#        [ 1107.74286455,   477.41252074],
#        [ 1427.88116805,   346.79262125],
#        [ 1689.49665375,   116.60456217],
#        [  296.41493524,  -169.47076169],
#        [  658.48258083,  -513.67413294],
#        [  800.02781212,  -900.54819203],
#        [  775.90924372, -1246.86861582]])

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6))


ax[0].scatter(pos_i[:,0], pos_i[:,1], label='initial', color='blue')
for i in range(0,pos_i.shape[0]):
    ax[0].text(pos_i[i,0], pos_i[i,1],f"{i}", color='orange')
ax[0].set_title('Initial Guess')
ax[0].grid(True)
ax[0].set_xlabel('x (mm)')
ax[0].set_ylabel('y (mm)')

ax[1].scatter(pos[:,0], pos[:,1], label='final', color='orange')
for i in range(0,pos.shape[0]):
    ax[1].text(pos[i,0], pos[i,1],f"{i}", color='blue')
ax[1].set_title('Final Solution')
ax[1].grid(True)
ax[1].set_xlabel('x (mm)')
ax[1].set_ylabel('y (mm)')
plt.savefig('final_positions.png')
plt.show()

# %% [markdown]
# ![title](drone_view.jpeg)

# %%
# Differences plot
diff = pos - pos_i[:,0:2]


fig, ax = plt.subplots(figsize=(12,12))

ax.scatter(diff[:,0], diff[:,1], color='red')

for i in range(0,diff.shape[0]):
    ax.text(diff[i,0], diff[i,1],f"{i}")

ax.grid(True)
ax.set_title("Differences from initial position")
ax.set_xlabel('x (mm)')
ax.set_ylabel('y (mm)')
plt.savefig('differences.png')
plt.show()

# %%
# Residual plot
rres = radius_residual(res.x)
rres
# Out:
# A 0     1.255178
# A 1     1.481895
# A 2     1.559341
# A 3     2.362298
# A 4     0.576072
# A 5     0.419151
# A 6     1.156512
# A 7     1.098995
# A 8     1.261646
# A 9     0.364182
# A 10    0.447067
# A 11    2.318286
# A 12   -0.647020
# A 13   -0.015334
# A 14    1.064835
# A 15   -0.067118
# A 16    1.736364
# A 17    1.240842
# A 18    4.390946
# A 19    0.515742
# A 20    0.441288
# A 21    0.140961
# A 22    1.587708
# A 23   -1.423649
# Name: 0, dtype: float64

# %%
# ij resdual
ijres = m_ij_residual(res.x)
plt.hist(ijres, bins='fd');
plt.title("Histogram of residuals")
plt.xlabel("Residual (mm)")
plt.grid(True)
plt.savefig("residual_histogram.png")

# %% [markdown]
# The API expects 3D coordinates (with a z value which is zero in this case). Therefore we add a column of zeros.

# %%
absres = np.abs(ijres)
pct = 90
p95 = np.percentile(absres, pct)

print(f"{pct}th percentile of residuals is {p95:4.2f} mm")
ijres_matrix = np.zeros_like(m_ij)
big_res = []
for r, i, j in zip(ijres, non_nan_indices[:,0], non_nan_indices[:,1]):
    if np.abs(r) > p95 and i > j:
        big_res.append([r,i,j])
    ijres_matrix[i,j] = r

for res in sorted(big_res):
    r,i,j = res
    print(f" res[{i},{j}] = {r:3.1f}")
# Out:
# 90th percentile of residuals is 1.84 mm
#  res[18,2] = -2.8
#  res[5,3] = -2.6
#  res[18,5] = -2.6
#  res[2,0] = -2.6
#  res[17,3] = -2.5
#  res[18,4] = -2.5
#  res[19,6] = -2.5
#  res[14,8] = -2.3
#  res[18,11] = -2.3
#  res[16,2] = -2.2
#  res[18,3] = -2.2
#  res[6,3] = -2.1
#  res[18,0] = -2.1
#  res[5,2] = -1.9
#  res[7,6] = -1.9
#  res[11,7] = -1.9
#  res[16,8] = -1.9
#  res[9,0] = -1.9
#  res[21,8] = 1.8
#  res[23,17] = 1.9
#  res[13,2] = 2.1
#  res[4,2] = 2.1
#  res[23,15] = 2.3
#  res[21,7] = 2.4
#  res[12,3] = 2.5
#  res[15,14] = 2.8
#  res[23,9] = 2.8
#  res[12,2] = 3.1

# %% [markdown]
# ## Output best estimates
#
# Write some json files...

# %%
result = np.zeros((n_ant, 3))
result[:,:-1] = np.round(pos/1000.0, 3)
result
# Out:
# array([[-0.068, -0.33 ,  0.   ],
#        [-0.285, -0.78 ,  0.   ],
#        [-0.61 , -1.033,  0.   ],
#        [-0.947, -1.113,  0.   ],
#        [-1.293, -1.078,  0.   ],
#        [-0.332, -0.035,  0.   ],
#        [-0.826,  0.031,  0.   ],
#        [-1.168,  0.262,  0.   ],
#        [-1.351,  0.557,  0.   ],
#        [-1.427,  0.897,  0.   ],
#        [-0.129,  0.309,  0.   ],
#        [-0.218,  0.798,  0.   ],
#        [-0.105,  1.195,  0.   ],
#        [ 0.118,  1.46 ,  0.   ],
#        [ 0.418,  1.636,  0.   ],
#        [ 0.258,  0.225,  0.   ],
#        [ 0.695,  0.462,  0.   ],
#        [ 1.108,  0.477,  0.   ],
#        [ 1.428,  0.347,  0.   ],
#        [ 1.689,  0.117,  0.   ],
#        [ 0.296, -0.169,  0.   ],
#        [ 0.658, -0.514,  0.   ],
#        [ 0.8  , -0.901,  0.   ],
#        [ 0.776, -1.247,  0.   ]])

# %%
json_result = {}
json_result["antenna_positions"] = result.tolist()

json_fname = f"{site_name}_processed_antenna_positions.json"
f = open(json_fname, "w")
f.write(json.dumps(json_result))
f.close()

pos_json = json.dumps(json_result, indent=4, separators=(',', ': '))
print(pos_json)
# Out:
# {
#     "antenna_positions": [
#         [
#             -0.068,
#             -0.33,
#             0.0
#         ],
#         [
#             -0.285,
#             -0.78,
#             0.0
#         ],
#         [
#             -0.61,
#             -1.033,
#             0.0
#         ],
#         [
#             -0.947,
#             -1.113,
#             0.0
#         ],
#         [
#             -1.293,
#             -1.078,
#             0.0
#         ],
#         [
#             -0.332,
#             -0.035,
#             0.0
#         ],
#         [
#             -0.826,
#             0.031,
#             0.0
#         ],
#         [
#             -1.168,
#             0.262,
#             0.0
#         ],
#         [
#             -1.351,
#             0.557,
#             0.0
#         ],
#         [
#             -1.427,
#             0.897,
#             0.0
#         ],
#         [
#             -0.129,
#             0.309,
#             0.0
#         ],
#         [
#             -0.218,
#             0.798,
#             0.0
#         ],
#         [
#             -0.105,
#             1.195,
#             0.0
#         ],
#         [
#             0.118,
#             1.46,
#             0.0
#         ],
#         [
#             0.418,
#             1.636,
#             0.0
#         ],
#         [
#             0.258,
#             0.225,
#             0.0
#         ],
#         [
#             0.695,
#             0.462,
#             0.0
#         ],
#         [
#             1.108,
#             0.477,
#             0.0
#         ],
#         [
#             1.428,
#             0.347,
#             0.0
#         ],
#         [
#             1.689,
#             0.117,
#             0.0
#         ],
#         [
#             0.296,
#             -0.169,
#             0.0
#         ],
#         [
#             0.658,
#             -0.514,
#             0.0
#         ],
#         [
#             0.8,
#             -0.901,
#             0.0
#         ],
#         [
#             0.776,
#             -1.247,
#             0.0
#         ]
#     ]
# }

# %% [markdown]
# The position file above is in a format suitable for uploading to the telescope api. Also for using as the calibrated_antenna_positions.json file in TART/software/containers/telescope_web_api/config_data.

# %%
print(f"tart_upload_antenna_positions --api https://api.elec.ac.nz/tart/{site_name} --pw=xxxx --file {json_fname}")
# Out:
# tart_upload_antenna_positions --api https://api.elec.ac.nz/tart/mg-tana --pw=xxxx --file mg-tana_processed_antenna_positions.json
